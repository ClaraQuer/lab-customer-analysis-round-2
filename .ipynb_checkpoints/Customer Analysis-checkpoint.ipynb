# %% [markdown]
# # Round 2

# %%
import pandas as pd 
import numpy as np

# %%
mca = pd.read_csv('files_for_lab/csv_files/marketing_customer_analysis.csv')
mca.shape
# Out:
# (10910, 26)

# %%
mca.columns
# Out:
# Index(['Unnamed: 0', 'Customer', 'State', 'Customer Lifetime Value',
#        'Response', 'Coverage', 'Education', 'Effective To Date',
#        'EmploymentStatus', 'Gender', 'Income', 'Location Code',
#        'Marital Status', 'Monthly Premium Auto', 'Months Since Last Claim',
#        'Months Since Policy Inception', 'Number of Open Complaints',
#        'Number of Policies', 'Policy Type', 'Policy', 'Renew Offer Type',
#        'Sales Channel', 'Total Claim Amount', 'Vehicle Class', 'Vehicle Size',
#        'Vehicle Type'],
#       dtype='object')

# %%
mca = mca.drop(['Unnamed: 0'], axis = 1)

# %%
mca.columns
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Response', 'Coverage',
#        'Education', 'Effective To Date', 'EmploymentStatus', 'Gender',
#        'Income', 'Location Code', 'Marital Status', 'Monthly Premium Auto',
#        'Months Since Last Claim', 'Months Since Policy Inception',
#        'Number of Open Complaints', 'Number of Policies', 'Policy Type',
#        'Policy', 'Renew Offer Type', 'Sales Channel', 'Total Claim Amount',
#        'Vehicle Class', 'Vehicle Size', 'Vehicle Type'],
#       dtype='object')

# %%
mca = mca.rename(columns={'EmploymentStatus': 'Employment Status',
                         'Number of Open Complaints': 'Number Of Open Complaints',
                         'Number of Policies': 'Number Of Policies'})


mca.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  DK49336     Arizona              4809.216960       No     Basic   College
# 1  KX64629  California              2228.525238       No     Basic   College
# 2  LZ68649  Washington             14947.917300       No     Basic  Bachelor
# 3  XL78013      Oregon             22332.439460      Yes  Extended   College
# 4  QA50777      Oregon              9025.067525       No   Premium  Bachelor
#
#   Effective To Date Employment Status Gender  Income  ...  \
# 0           2/18/11          Employed      M   48029  ...
# 1           1/18/11        Unemployed      F       0  ...
# 2           2/10/11          Employed      M   22139  ...
# 3           1/11/11          Employed      M   49078  ...
# 4           1/17/11     Medical Leave      F   23675  ...
#
#   Number Of Open Complaints Number Of Policies     Policy Type        Policy  \
# 0                       0.0                  9  Corporate Auto  Corporate L3
# 1                       0.0                  1   Personal Auto   Personal L3
# 2                       0.0                  2   Personal Auto   Personal L3
# 3                       0.0                  2  Corporate Auto  Corporate L3
# 4                       NaN                  7   Personal Auto   Personal L2
#
#    Renew Offer Type  Sales Channel  Total Claim Amount  Vehicle Class  \
# 0            Offer3          Agent          292.800000  Four-Door Car
# 1            Offer4    Call Center          744.924331  Four-Door Car
# 2            Offer3    Call Center          480.000000            SUV
# 3            Offer2         Branch          484.013411  Four-Door Car
# 4            Offer1         Branch          707.925645  Four-Door Car
#
#   Vehicle Size Vehicle Type
# 0      Medsize          NaN
# 1      Medsize          NaN
# 2      Medsize            A
# 3      Medsize            A
# 4      Medsize          NaN
#
# [5 rows x 25 columns]

# %%
mca = mca[['Customer', 'State', 'Gender', 'Marital Status','Education', 'Employment Status', 'Income', 
     'Customer Lifetime Value', 'Response', 'Coverage','Effective To Date','Location Code',  'Monthly Premium Auto',
     'Months Since Last Claim', 'Months Since Policy Inception',
     'Number Of Open Complaints', 'Number Of Policies', 'Policy Type',
     'Policy', 'Renew Offer Type', 'Sales Channel', 'Total Claim Amount',
     'Vehicle Class', 'Vehicle Size', 'Vehicle Type']]

mca.head()
# Out:
#   Customer       State Gender Marital Status Education Employment Status  \
# 0  DK49336     Arizona      M        Married   College          Employed
# 1  KX64629  California      F         Single   College        Unemployed
# 2  LZ68649  Washington      M         Single  Bachelor          Employed
# 3  XL78013      Oregon      M         Single   College          Employed
# 4  QA50777      Oregon      F        Married  Bachelor     Medical Leave
#
#    Income  Customer Lifetime Value Response  Coverage  ...  \
# 0   48029              4809.216960       No     Basic  ...
# 1       0              2228.525238       No     Basic  ...
# 2   22139             14947.917300       No     Basic  ...
# 3   49078             22332.439460      Yes  Extended  ...
# 4   23675              9025.067525       No   Premium  ...
#
#   Number Of Open Complaints Number Of Policies     Policy Type        Policy  \
# 0                       0.0                  9  Corporate Auto  Corporate L3
# 1                       0.0                  1   Personal Auto   Personal L3
# 2                       0.0                  2   Personal Auto   Personal L3
# 3                       0.0                  2  Corporate Auto  Corporate L3
# 4                       NaN                  7   Personal Auto   Personal L2
#
#    Renew Offer Type  Sales Channel  Total Claim Amount  Vehicle Class  \
# 0            Offer3          Agent          292.800000  Four-Door Car
# 1            Offer4    Call Center          744.924331  Four-Door Car
# 2            Offer3    Call Center          480.000000            SUV
# 3            Offer2         Branch          484.013411  Four-Door Car
# 4            Offer1         Branch          707.925645  Four-Door Car
#
#   Vehicle Size Vehicle Type
# 0      Medsize          NaN
# 1      Medsize          NaN
# 2      Medsize            A
# 3      Medsize            A
# 4      Medsize          NaN
#
# [5 rows x 25 columns]

# %%
mca.dtypes
# Out:
# Customer                          object
# State                             object
# Gender                            object
# Marital Status                    object
# Education                         object
# Employment Status                 object
# Income                             int64
# Customer Lifetime Value          float64
# Response                          object
# Coverage                          object
# Effective To Date                 object
# Location Code                     object
# Monthly Premium Auto               int64
# Months Since Last Claim          float64
# Months Since Policy Inception      int64
# Number Of Open Complaints        float64
# Number Of Policies                 int64
# Policy Type                       object
# Policy                            object
# Renew Offer Type                  object
# Sales Channel                     object
# Total Claim Amount               float64
# Vehicle Class                     object
# Vehicle Size                      object
# Vehicle Type                      object
# dtype: object

# %%
mca._get_numeric_data()
# Out:
#        Income  Customer Lifetime Value  Monthly Premium Auto  \
# 0       48029              4809.216960                    61
# 1           0              2228.525238                    64
# 2       22139             14947.917300                   100
# 3       49078             22332.439460                    97
# 4       23675              9025.067525                   117
# ...       ...                      ...                   ...
# 10905       0             15563.369440                   253
# 10906   61146              5259.444853                    65
# 10907   39837             23893.304100                   201
# 10908   64195             11971.977650                   158
# 10909       0              6857.519928                   101
#
#        Months Since Last Claim  Months Since Policy Inception  \
# 0                          7.0                             52
# 1                          3.0                             26
# 2                         34.0                             31
# 3                         10.0                              3
# 4                          NaN                             31
# ...                        ...                            ...
# 10905                      NaN                             40
# 10906                      7.0                             68
# 10907                     11.0                             63
# 10908                      0.0                             27
# 10909                     31.0                              1
#
#        Number Of Open Complaints  Number Of Policies  Total Claim Amount
# 0                            0.0                   9          292.800000
# 1                            0.0                   1          744.924331
# 2                            0.0                   2          480.000000
# 3                            0.0                   2          484.013411
# 4                            NaN                   7          707.925645
# ...                          ...                 ...                 ...
# 10905                        NaN                   7         1214.400000
# 10906                        0.0                   6          273.018929
# 10907                        0.0                   2          381.306996
# 10908                        4.0                   6          618.288849
# 10909                        0.0                   3         1021.719397
#
# [10910 rows x 8 columns]

# %%
mca.select_dtypes(['object'])
# Out:
#       Customer       State Gender Marital Status Education Employment Status  \
# 0      DK49336     Arizona      M        Married   College          Employed
# 1      KX64629  California      F         Single   College        Unemployed
# 2      LZ68649  Washington      M         Single  Bachelor          Employed
# 3      XL78013      Oregon      M         Single   College          Employed
# 4      QA50777      Oregon      F        Married  Bachelor     Medical Leave
# ...        ...         ...    ...            ...       ...               ...
# 10905  FE99816      Nevada      F        Married  Bachelor        Unemployed
# 10906  KX53892      Oregon      F        Married   College          Employed
# 10907  TL39050     Arizona      F        Married  Bachelor          Employed
# 10908  WA60547  California      F       Divorced   College          Employed
# 10909  IV32877         NaN      M         Single  Bachelor        Unemployed
#
#       Response  Coverage Effective To Date Location Code     Policy Type  \
# 0           No     Basic           2/18/11      Suburban  Corporate Auto
# 1           No     Basic           1/18/11      Suburban   Personal Auto
# 2           No     Basic           2/10/11      Suburban   Personal Auto
# 3          Yes  Extended           1/11/11      Suburban  Corporate Auto
# 4           No   Premium           1/17/11      Suburban   Personal Auto
# ...        ...       ...               ...           ...             ...
# 10905       No   Premium           1/19/11      Suburban   Personal Auto
# 10906       No     Basic            1/6/11         Urban   Personal Auto
# 10907       No  Extended            2/6/11         Rural  Corporate Auto
# 10908       No   Premium           2/13/11         Urban   Personal Auto
# 10909      NaN     Basic            1/8/11      Suburban   Personal Auto
#
#              Policy Renew Offer Type Sales Channel  Vehicle Class  \
# 0      Corporate L3           Offer3         Agent  Four-Door Car
# 1       Personal L3           Offer4   Call Center  Four-Door Car
# 2       Personal L3           Offer3   Call Center            SUV
# 3      Corporate L3           Offer2        Branch  Four-Door Car
# 4       Personal L2           Offer1        Branch  Four-Door Car
# ...             ...              ...           ...            ...
# 10905   Personal L1           Offer3           Web     Luxury Car
# 10906   Personal L3           Offer2        Branch  Four-Door Car
# 10907  Corporate L3           Offer1           Web     Luxury SUV
# 10908   Personal L1           Offer1        Branch            SUV
# 10909   Personal L1           Offer4           Web            SUV
#
#       Vehicle Size Vehicle Type
# 0          Medsize          NaN
# 1          Medsize          NaN
# 2          Medsize            A
# 3          Medsize            A
# 4          Medsize          NaN
# ...            ...          ...
# 10905      Medsize            A
# 10906      Medsize            A
# 10907      Medsize          NaN
# 10908      Medsize            A
# 10909      Medsize          NaN
#
# [10910 rows x 17 columns]

# %%
mca.duplicated().sum()
mca = mca.drop_duplicates()
mca.isna().sum()
# Out:
# Customer                            0
# State                             614
# Gender                              0
# Marital Status                      0
# Education                           0
# Employment Status                   0
# Income                              0
# Customer Lifetime Value             0
# Response                          614
# Coverage                            0
# Effective To Date                   0
# Location Code                       0
# Monthly Premium Auto                0
# Months Since Last Claim           623
# Months Since Policy Inception       0
# Number Of Open Complaints         623
# Number Of Policies                  0
# Policy Type                         0
# Policy                              0
# Renew Offer Type                    0
# Sales Channel                       0
# Total Claim Amount                  0
# Vehicle Class                     608
# Vehicle Size                      608
# Vehicle Type                     5465
# dtype: int64

# %%
pd.set_option('display.max_columns', None)

mca[mca['State'].isna() & mca['Response'].isna()] #The ones with no response have no State Assigned. Maybe that is because they coulddn't ask.

mca[(mca['Months Since Last Claim'].isna() & mca['Number Of Open Complaints'].isna())] #The ones with no data about open complaints also have no data for previous complaints, suggesting they are new costumers.
# Out:
#       Customer       State Gender Marital Status             Education  \
# 4      QA50777      Oregon      F        Married              Bachelor
# 23     NQ71171  California      M        Married              Bachelor
# 51     FT56968     Arizona      M        Married  High School or Below
# 59     EP83939     Arizona      M        Married  High School or Below
# 67     KR35099  Washington      M         Single               College
# ...        ...         ...    ...            ...                   ...
# 10801  AP56340  Washington      M        Married              Bachelor
# 10816  AW71157  California      M       Divorced               College
# 10833  OQ99704  Washington      F        Married              Bachelor
# 10834  FU99476  Washington      M       Divorced  High School or Below
# 10905  FE99816      Nevada      F        Married              Bachelor
#
#       Employment Status  Income  Customer Lifetime Value Response  Coverage  \
# 4         Medical Leave   23675              9025.067525       No   Premium
# 23             Employed   70174              5107.071054       No     Basic
# 51             Employed   22398              2590.096027       No     Basic
# 59             Employed   91416              5575.751228       No     Basic
# 67             Employed   60920              7507.455372      Yes     Basic
# ...                 ...     ...                      ...      ...       ...
# 10801          Disabled   13103              5384.671725       No     Basic
# 10816          Employed   50097              5531.723723       No     Basic
# 10833          Employed   52801              3981.775889       No     Basic
# 10834          Employed   74422              6770.306834       No  Extended
# 10905        Unemployed       0             15563.369440       No   Premium
#
#       Effective To Date Location Code  Monthly Premium Auto  \
# 4               1/17/11      Suburban                   117
# 23               2/2/11         Rural                    64
# 51               1/3/11      Suburban                    67
# 59              1/26/11         Rural                    69
# 67               2/6/11         Urban                    64
# ...                 ...           ...                   ...
# 10801           2/26/11      Suburban                    72
# 10816           1/16/11         Rural                    71
# 10833           2/11/11         Urban                   100
# 10834           2/22/11         Rural                    85
# 10905           1/19/11      Suburban                   253
#
#        Months Since Last Claim  Months Since Policy Inception  \
# 4                          NaN                             31
# 23                         NaN                             80
# 51                         NaN                             76
# 59                         NaN                             39
# 67                         NaN                             61
# ...                        ...                            ...
# 10801                      NaN                             32
# 10816                      NaN                             81
# 10833                      NaN                             78
# 10834                      NaN                              3
# 10905                      NaN                             40
#
#        Number Of Open Complaints  Number Of Policies    Policy Type  \
# 4                            NaN                   7  Personal Auto
# 23                           NaN                   7  Personal Auto
# 51                           NaN                   1  Personal Auto
# 59                           NaN                   5  Personal Auto
# 67                           NaN                   2  Personal Auto
# ...                          ...                 ...            ...
# 10801                        NaN                   7  Personal Auto
# 10816                        NaN                   5  Personal Auto
# 10833                        NaN                   1  Personal Auto
# 10834                        NaN                   3  Personal Auto
# 10905                        NaN                   7  Personal Auto
#
#             Policy Renew Offer Type Sales Channel  Total Claim Amount  \
# 4      Personal L2           Offer1        Branch          707.925645
# 23     Personal L2           Offer1         Agent          128.900320
# 51     Personal L1           Offer1         Agent          321.600000
# 59     Personal L3           Offer2   Call Center          109.904496
# 67     Personal L3           Offer2         Agent          231.201886
# ...            ...              ...           ...                 ...
# 10801  Personal L2           Offer1         Agent          458.003651
# 10816  Personal L1           Offer3           Web           17.484679
# 10833  Personal L3           Offer2        Branch          475.200880
# 10834  Personal L1           Offer1   Call Center           95.338505
# 10905  Personal L1           Offer3           Web         1214.400000
#
#        Vehicle Class Vehicle Size Vehicle Type
# 4      Four-Door Car      Medsize          NaN
# 23     Four-Door Car      Medsize          NaN
# 51     Four-Door Car        Large            A
# 59     Four-Door Car      Medsize          NaN
# 67      Two-Door Car      Medsize            A
# ...              ...          ...          ...
# 10801  Four-Door Car      Medsize            A
# 10816  Four-Door Car      Medsize            A
# 10833            SUV        Small            A
# 10834  Four-Door Car      Medsize            A
# 10905     Luxury Car      Medsize            A
#
# [623 rows x 25 columns]

# %%
mca['Months Since Last Claim'] = mca['Months Since Last Claim'].fillna(0) #We change the values to 0 because if there is no recolection of a previous complaint, it is the same as if you had a 0.
mca['Number Of Open Complaints'] = mca['Number Of Open Complaints'].fillna(0) #We do the same here for the same reason.
mca['Response'] = mca['Response'].fillna('No') #If you don't know if someone responded, they probably didn't, so we change it to "No".
mca.isna().sum()
# Out:
# Customer                            0
# State                             614
# Gender                              0
# Marital Status                      0
# Education                           0
# Employment Status                   0
# Income                              0
# Customer Lifetime Value             0
# Response                            0
# Coverage                            0
# Effective To Date                   0
# Location Code                       0
# Monthly Premium Auto                0
# Months Since Last Claim             0
# Months Since Policy Inception       0
# Number Of Open Complaints           0
# Number Of Policies                  0
# Policy Type                         0
# Policy                              0
# Renew Offer Type                    0
# Sales Channel                       0
# Total Claim Amount                  0
# Vehicle Class                     608
# Vehicle Size                      608
# Vehicle Type                     5465
# dtype: int64

# %%
mca['State'].value_counts()/(len(mca['State']))*100 #We check if there is a vast majority in one state big enough to assume the NAN are from there aswell. We see this is not the case.
# Out:
# California    32.631289
# Oregon        26.643981
# Arizona       17.787179
# Nevada         9.123517
# Washington     8.167019
# Name: State, dtype: float64

# %%
mca['State'] = mca['State'].fillna('Unknown') #We decide to change them to 'Unkown' because we can't know for sure.
mca.isna().sum()
# Out:
# Customer                            0
# State                               0
# Gender                              0
# Marital Status                      0
# Education                           0
# Employment Status                   0
# Income                              0
# Customer Lifetime Value             0
# Response                            0
# Coverage                            0
# Effective To Date                   0
# Location Code                       0
# Monthly Premium Auto                0
# Months Since Last Claim             0
# Months Since Policy Inception       0
# Number Of Open Complaints           0
# Number Of Policies                  0
# Policy Type                         0
# Policy                              0
# Renew Offer Type                    0
# Sales Channel                       0
# Total Claim Amount                  0
# Vehicle Class                     608
# Vehicle Size                      608
# Vehicle Type                     5465
# dtype: int64

# %%
mca['Vehicle Class'].value_counts()/(len(mca['Vehicle Class']))*100 #Since there are so many different types, we will assign "Unkown" to the NaNs.
# Out:
# Four-Door Car    47.824887
# Two-Door Car     19.424262
# SUV              18.476961
# Sports Car        5.040007
# Luxury SUV        1.912995
# Luxury Car        1.729054
# Name: Vehicle Class, dtype: float64

# %%
mca['Vehicle Size'].value_counts()/(len(mca['Vehicle Size']))*100 #We will assign "Unkown" to the NaNs for the same reason as before. We think assuming they are Medium just because the majority are is not right.
# Out:
# Medsize    66.522579
# Small      18.044698
# Large       9.840890
# Name: Vehicle Size, dtype: float64

# %%
mca['Vehicle Type'].value_counts()/(len(mca['Vehicle Type']))*100 #Since there is only one type, and it is "A", we are assuming the other ones are "Not A", so we will use that string to replace the NaNs.
# Out:
# A    49.737883
# Name: Vehicle Type, dtype: float64

# %%
mca['Vehicle Class'] = mca['Vehicle Class'].fillna('Unknown')
mca['Vehicle Size'] = mca['Vehicle Size'].fillna('Unknown')
mca['Vehicle Type'] = mca['Vehicle Type'].fillna('not A')

mca.isna().sum() #As we can see, there are no more NaN values.
# Out:
# Customer                         0
# State                            0
# Gender                           0
# Marital Status                   0
# Education                        0
# Employment Status                0
# Income                           0
# Customer Lifetime Value          0
# Response                         0
# Coverage                         0
# Effective To Date                0
# Location Code                    0
# Monthly Premium Auto             0
# Months Since Last Claim          0
# Months Since Policy Inception    0
# Number Of Open Complaints        0
# Number Of Policies               0
# Policy Type                      0
# Policy                           0
# Renew Offer Type                 0
# Sales Channel                    0
# Total Claim Amount               0
# Vehicle Class                    0
# Vehicle Size                     0
# Vehicle Type                     0
# dtype: int64

# %%
import time
from datetime import date

# %%
mca['Effective To Date'] = pd.to_datetime(mca['Effective To Date'], errors = 'coerce')

# %%
mca['Effective To Date'] = mca['Effective To Date'].dt.strftime("%d/%m/%Y")

# %%
mca['Effective To Date'] = pd.to_datetime(mca['Effective To Date'], errors = 'coerce')
mca['Month'] = mca['Effective To Date'].dt.month

# %%
mca['Month']
# Out:
# 0         2
# 1         1
# 2        10
# 3        11
# 4         1
#          ..
# 10905     1
# 10906     6
# 10907     6
# 10908     2
# 10909     8
# Name: Month, Length: 10873, dtype: int64

# %%
mca[mca['Month'] <= 3]
# Out:
#       Customer       State Gender Marital Status             Education  \
# 0      DK49336     Arizona      M        Married               College
# 1      KX64629  California      F         Single               College
# 4      QA50777      Oregon      F        Married              Bachelor
# 5      HO81102     Unknown      M       Divorced  High School or Below
# 6      IW72280  California      F        Married                Doctor
# ...        ...         ...    ...            ...                   ...
# 10901  RY92254  Washington      M        Married              Bachelor
# 10902  PP30874  California      F        Married  High School or Below
# 10904  QI63521      Nevada      M         Single  High School or Below
# 10905  FE99816      Nevada      F        Married              Bachelor
# 10908  WA60547  California      F       Divorced               College
#
#       Employment Status  Income  Customer Lifetime Value Response  Coverage  \
# 0              Employed   48029              4809.216960       No     Basic
# 1            Unemployed       0              2228.525238       No     Basic
# 4         Medical Leave   23675              9025.067525       No   Premium
# 5              Employed   50549              4745.181764       No     Basic
# 6              Employed   37405              5035.035257       No     Basic
# ...                 ...     ...                      ...      ...       ...
# 10901          Employed   33531              4547.892543       No   Premium
# 10902          Employed   28304              3579.023825       No  Extended
# 10904        Unemployed       0             19228.463620       No     Basic
# 10905        Unemployed       0             15563.369440       No   Premium
# 10908          Employed   64195             11971.977650       No   Premium
#
#       Effective To Date Location Code  Monthly Premium Auto  \
# 0            2011-02-18      Suburban                    61
# 1            2011-01-18      Suburban                    64
# 4            2011-01-17      Suburban                   117
# 5            2011-02-14      Suburban                    61
# 6            2011-02-14         Urban                    63
# ...                 ...           ...                   ...
# 10901        2011-01-13      Suburban                   116
# 10902        2011-01-24      Suburban                    91
# 10904        2011-02-24      Suburban                   187
# 10905        2011-01-19      Suburban                   253
# 10908        2011-02-13         Urban                   158
#
#        Months Since Last Claim  Months Since Policy Inception  \
# 0                          7.0                             52
# 1                          3.0                             26
# 4                          0.0                             31
# 5                          2.0                             73
# 6                          8.0                             99
# ...                        ...                            ...
# 10901                     11.0                             15
# 10902                     10.0                             30
# 10904                     14.0                             32
# 10905                      0.0                             40
# 10908                      0.0                             27
#
#        Number Of Open Complaints  Number Of Policies     Policy Type  \
# 0                            0.0                   9  Corporate Auto
# 1                            0.0                   1   Personal Auto
# 4                            0.0                   7   Personal Auto
# 5                            0.0                   7   Personal Auto
# 6                            3.0                   4  Corporate Auto
# ...                          ...                 ...             ...
# 10901                        0.0                   1   Personal Auto
# 10902                        2.0                   1   Personal Auto
# 10904                        0.0                   2   Personal Auto
# 10905                        0.0                   7   Personal Auto
# 10908                        4.0                   6   Personal Auto
#
#              Policy Renew Offer Type Sales Channel  Total Claim Amount  \
# 0      Corporate L3           Offer3         Agent          292.800000
# 1       Personal L3           Offer4   Call Center          744.924331
# 4       Personal L2           Offer1        Branch          707.925645
# 5       Personal L3           Offer1         Agent          292.800000
# 6      Corporate L2           Offer2        Branch          287.556107
# ...             ...              ...           ...                 ...
# 10901   Personal L3           Offer4         Agent          801.577478
# 10902   Personal L2           Offer2         Agent          655.200000
# 10904   Personal L2           Offer1        Branch          897.600000
# 10905   Personal L1           Offer3           Web         1214.400000
# 10908   Personal L1           Offer1        Branch          618.288849
#
#        Vehicle Class Vehicle Size Vehicle Type  Month
# 0      Four-Door Car      Medsize        not A      2
# 1      Four-Door Car      Medsize        not A      1
# 4      Four-Door Car      Medsize        not A      1
# 5      Four-Door Car      Medsize            A      2
# 6      Four-Door Car      Medsize        not A      2
# ...              ...          ...          ...    ...
# 10901   Two-Door Car      Medsize        not A      1
# 10902  Four-Door Car      Medsize            A      1
# 10904     Luxury SUV      Medsize            A      2
# 10905     Luxury Car      Medsize            A      1
# 10908            SUV      Medsize            A      2
#
# [7643 rows x 26 columns]

# %% [markdown]
# # Round 3

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
mca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10873 entries, 0 to 10909
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer                       10873 non-null  object
#  1   State                          10873 non-null  object
#  2   Gender                         10873 non-null  object
#  3   Marital Status                 10873 non-null  object
#  4   Education                      10873 non-null  object
#  5   Employment Status              10873 non-null  object
#  6   Income                         10873 non-null  int64
#  7   Customer Lifetime Value        10873 non-null  float64
#  8   Response                       10873 non-null  object
#  9   Coverage                       10873 non-null  object
#  10  Effective To Date              10873 non-null  datetime64[ns]
#  11  Location Code                  10873 non-null  object
#  12  Monthly Premium Auto           10873 non-null  int64
#  13  Months Since Last Claim        10873 non-null  float64
#  14  Months Since Policy Inception  10873 non-null  int64
#  15  Number Of Open Complaints      10873 non-null  float64
#  16  Number Of Policies             10873 non-null  int64
#  17  Policy Type                    10873 non-null  object
#  18  Policy                         10873 non-null  object
#  19  Renew Offer Type               10873 non-null  object
#  20  Sales Channel                  10873 non-null  object
#  21  Total Claim Amount             10873 non-null  float64
#  22  Vehicle Class                  10873 non-null  object
#  23  Vehicle Size                   10873 non-null  object
#  24  Vehicle Type                   10873 non-null  object
#  25  Month                          10873 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int64(5), object(16)
# memory usage: 2.2+ MB

# %%
mca.describe(datetime_is_numeric=True).T
# Out:
#                                  count                           mean  \
# Income                         10873.0                   37537.101444
# Customer Lifetime Value        10873.0                     8016.88172
# Effective To Date                10873  2011-03-29 12:07:28.965327104
# Monthly Premium Auto           10873.0                      93.216684
# Months Since Last Claim        10873.0                      14.277292
# Months Since Policy Inception  10873.0                      48.098777
# Number Of Open Complaints      10873.0                       0.361538
# Number Of Policies             10873.0                       2.977467
# Total Claim Amount             10873.0                     434.902879
# Month                          10873.0                       3.472179
#
#                                                min                  25%  \
# Income                                         0.0                  0.0
# Customer Lifetime Value                1898.007675          4014.453113
# Effective To Date              2011-01-01 00:00:00  2011-01-25 00:00:00
# Monthly Premium Auto                          61.0                 68.0
# Months Since Last Claim                        0.0                  5.0
# Months Since Policy Inception                  0.0                 24.0
# Number Of Open Complaints                      0.0                  0.0
# Number Of Policies                             1.0                  1.0
# Total Claim Amount                        0.099007           271.014511
# Month                                          1.0                  1.0
#
#                                                50%                  75%  \
# Income                                     33811.0              62262.0
# Customer Lifetime Value                5768.830622          8996.774075
# Effective To Date              2011-02-19 00:00:00  2011-05-01 00:00:00
# Monthly Premium Auto                          83.0                109.0
# Months Since Last Claim                       13.0                 23.0
# Months Since Policy Inception                 48.0                 71.0
# Number Of Open Complaints                      0.0                  0.0
# Number Of Policies                             2.0                  4.0
# Total Claim Amount                      383.363758                547.2
# Month                                          2.0                  5.0
#
#                                                max          std
# Income                                     99981.0  30362.07835
# Customer Lifetime Value                83325.38119  6884.829202
# Effective To Date              2011-12-02 00:00:00          NaN
# Monthly Premium Auto                         298.0    34.454801
# Months Since Last Claim                       35.0    10.399697
# Months Since Policy Inception                 99.0    27.929932
# Number Of Open Complaints                      5.0     0.889177
# Number Of Policies                             9.0     2.397752
# Total Claim Amount                     2893.239678   292.233402
# Month                                         12.0      3.32872

# %%
mca.describe(datetime_is_numeric=True, include = object).T
# Out:
#                    count unique            top  freq
# Customer           10873   9134        DQ50258     5
# State              10873      6     California  3548
# Gender             10873      2              F  5554
# Marital Status     10873      3        Married  6298
# Education          10873      5       Bachelor  3259
# Employment Status  10873      5       Employed  6764
# Response           10873      2             No  9409
# Coverage           10873      3          Basic  6635
# Location Code      10873      3       Suburban  6879
# Policy Type        10873      3  Personal Auto  8102
# Policy             10873      9    Personal L3  4108
# Renew Offer Type   10873      4         Offer1  4471
# Sales Channel      10873      4          Agent  4111
# Vehicle Class      10873      7  Four-Door Car  5200
# Vehicle Size       10873      4        Medsize  7233
# Vehicle Type       10873      2          not A  5465

# %%
sns.countplot(x = 'Response', data = mca)
plt.show()

# %%
sns.countplot(x = 'Sales Channel', data = mca, hue = 'Response')
plt.show()

# %%
sns.histplot(x = 'Total Claim Amount', data = mca, hue = 'Response', binwidth = 100, multiple = 'stack')
plt.show()

# %%
sns.histplot(x = 'Income', data = mca, hue = 'Response', binwidth = 5000, multiple = 'stack')
plt.show()
